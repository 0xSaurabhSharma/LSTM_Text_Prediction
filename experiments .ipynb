# %%
# !pip install -r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 5)) (2.18.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (1.41.1)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 8)) (0.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (1.70.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (0.37.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 5)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 5)) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 6)) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 6)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (8.1.8)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (17.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (1.24.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (0.45.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (4.0.12)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 1)) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=10.14.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r /content/drive/MyDrive/GenAI_Udemy_Projects/LSTM_Text_Prediction/requirements.txt (line 7)) (0.1.2)

# %%
# Data Collection
import nltk
nltk.download('gutenberg')
from nltk.corpus import gutenberg

import pandas as pd

# Load the dataset
data = gutenberg.raw('shakespeare-hamlet.txt')
# saving to file
with open('hamlet.txt', 'w') as file:
  file.write(data)
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %%
## data preprocessing

import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

## load the dataset
with open('hamlet.txt','r') as file:
  text=file.read().lower()

## Tokenize text
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1
total_words
# Out:
# 4818

# %%
# text = '''good morning
# i like apple
# you are the wizard
# my name is harry potter
# The sun is shining brightly today.
# Birds are singing in the trees.
# A gentle breeze is blowing.
# The flowers are blooming beautifully.
# The sky is a clear blue.
# Clouds drift slowly across it.
# A small dog runs happily.
# Children are playing in the park.
# Laughter fills the air.
# '''

# %% [markdown]
# Here, we are converting a text into lines, a line into a string of numbers and then taking each num-word and adding it to input sequence.
# Each num-word contains sequence of previous word like:
# *   i
# *   i am
# *   i am the
# *   i am the voldimort
#
# And then adding padding to it for uniform length

# %%
## create input sequence
input_sequence=[]
# print('############################')
for line in text.split('\n'):
  token_list=tokenizer.texts_to_sequences([line])[0]
  # print('token-list=========================')
  # print(token_list)
  # print('token len', len(token_list))
  for i in range(1, len(token_list)):
    # print('range len',range(1,len(token_list)))
    # print(token_list[:i+1])
    n_gram_sequence = token_list[:i + 1]
    # print('n----',n_gram_sequence)
    input_sequence.append(n_gram_sequence)
    # print('i----',input_sequence)
# print('############################')

# %%
# input_sequence

# %%
max_sequence_len = max([len(x) for x in input_sequence])
max_sequence_len
# Out:
# 14

# %%
input_sequence = np.array(pad_sequences(input_sequence, maxlen = max_sequence_len))
input_sequence
# Out:
# array([[   0,    0,    0, ...,    0,    1,  687],
#        [   0,    0,    0, ...,    1,  687,    4],
#        [   0,    0,    0, ...,  687,    4,   45],
#        ...,
#        [   0,    0,    0, ...,    4,   45, 1047],
#        [   0,    0,    0, ...,   45, 1047,    4],
#        [   0,    0,    0, ..., 1047,    4,  193]], dtype=int32)

# %%
# for i in range(0,100):
#   print(input_sequence[i])

# %%
## create predicitors and label
import tensorflow as tf
x,y = input_sequence[:,:-1], input_sequence[:,-1]

# %%
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)

# %%
## Train our LSTM rnn

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, GRU

# Define the model
# model = Sequential()
# model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
# model.add(LSTM(150, return_sequences=True))
# model.add(Dropout(0.2))
# model.add(LSTM(100))
# model.add(Dense(total_words, activation="softmax"))

model = Sequential([
    Embedding(total_words, 100, input_length=max_sequence_len-1),
    LSTM(150, return_sequences=True),
    Dropout(0.2),
    LSTM(100),
    Dense(total_words, activation="softmax")
])

# Compile the model
# model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=['accuracy'])

model.compile(loss="categorical_crossentropy",
              optimizer='adam',
              metrics=['accuracy'])
model.build((None, max_sequence_len-1))
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)              │ (None, 13, 100)             │         481,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_10 (LSTM)                       │ (None, 13, 150)             │         150,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 13, 150)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_11 (LSTM)                       │ (None, 100)                 │         100,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 4818)                │         486,618 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,219,418 (4.65 MB)
#  Trainable params: 1,219,418 (4.65 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("Training data shapes:")
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# Training data shapes:
# x_train shape: (20585, 13)
# y_train shape: (20585, 4818)
# x_test shape: (5147, 13)
# y_test shape: (5147, 4818)

# %%
# ## Train the model
# history = model.fit(x_train,y_train, epochs = 50, validation_data=(x_test,y_test,))

# history = model.fit(X_train, y_train, epochs=100, batch_size=64, callbacks=[early_stopping])

# Train the model
history = model.fit(
    x_train,
    y_train,
    epochs=150,
    batch_size=64,
    validation_data=(x_test, y_test),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 100ms/step - accuracy: 0.3199 - loss: 3.2635 - val_accuracy: 0.0573 - val_loss: 9.8229
# Epoch 2/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 30s 93ms/step - accuracy: 0.3305 - loss: 3.2310 - val_accuracy: 0.0575 - val_loss: 9.8982
# Epoch 3/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 97ms/step - accuracy: 0.3368 - loss: 3.1893 - val_accuracy: 0.0563 - val_loss: 9.9735
# Epoch 4/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 95ms/step - accuracy: 0.3412 - loss: 3.1572 - val_accuracy: 0.0579 - val_loss: 10.0347
# Epoch 5/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 98ms/step - accuracy: 0.3448 - loss: 3.1384 - val_accuracy: 0.0540 - val_loss: 10.0959
# Epoch 6/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 33s 102ms/step - accuracy: 0.3472 - loss: 3.1287 - val_accuracy: 0.0573 - val_loss: 10.1701
# Epoch 7/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 97ms/step - accuracy: 0.3516 - loss: 3.0862 - val_accuracy: 0.0569 - val_loss: 10.2263
# Epoch 8/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 34s 105ms/step - accuracy: 0.3573 - loss: 3.0652 - val_accuracy: 0.0560 - val_loss: 10.2820
# Epoch 9/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 97ms/step - accuracy: 0.3650 - loss: 3.0197 - val_accuracy: 0.0563 - val_loss: 10.3360
# Epoch 10/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 99ms/step - accuracy: 0.3684 - loss: 2.9984 - val_accuracy: 0.0550 - val_loss: 10.4010
# Epoch 11/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - accuracy: 0.3770 - loss: 2.9501 - val_accuracy: 0.0538 - val_loss: 10.4328
# Epoch 12/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - accuracy: 0.3813 - loss: 2.9226 - val_accuracy: 0.0536 - val_loss: 10.5049
# Epoch 13/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.3815 - loss: 2.9182 - val_accuracy: 0.0552 - val_loss: 10.5754
# Epoch 14/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.3862 - loss: 2.8782 - val_accuracy: 0.0561 - val_loss: 10.6100
# Epoch 15/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - accuracy: 0.3924 - loss: 2.8455 - val_accuracy: 0.0556 - val_loss: 10.6630
# Epoch 16/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 43s 99ms/step - accuracy: 0.3979 - loss: 2.8247 - val_accuracy: 0.0544 - val_loss: 10.7283
# Epoch 17/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 97ms/step - accuracy: 0.4022 - loss: 2.8105 - val_accuracy: 0.0552 - val_loss: 10.7872
# Epoch 18/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.4109 - loss: 2.7637 - val_accuracy: 0.0546 - val_loss: 10.8372
# Epoch 19/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.4093 - loss: 2.7577 - val_accuracy: 0.0521 - val_loss: 10.8778
# Epoch 20/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 102ms/step - accuracy: 0.4182 - loss: 2.7347 - val_accuracy: 0.0521 - val_loss: 10.9504
# Epoch 21/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 99ms/step - accuracy: 0.4226 - loss: 2.6859 - val_accuracy: 0.0581 - val_loss: 10.9741
# Epoch 22/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.4287 - loss: 2.6686 - val_accuracy: 0.0548 - val_loss: 11.0125
# Epoch 23/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 97ms/step - accuracy: 0.4323 - loss: 2.6472 - val_accuracy: 0.0560 - val_loss: 11.0704
# Epoch 24/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 92ms/step - accuracy: 0.4370 - loss: 2.6233 - val_accuracy: 0.0527 - val_loss: 11.1203
# Epoch 25/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 95ms/step - accuracy: 0.4391 - loss: 2.6156 - val_accuracy: 0.0556 - val_loss: 11.1849
# Epoch 26/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 97ms/step - accuracy: 0.4416 - loss: 2.5829 - val_accuracy: 0.0544 - val_loss: 11.2023
# Epoch 27/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 97ms/step - accuracy: 0.4438 - loss: 2.5647 - val_accuracy: 0.0560 - val_loss: 11.2618
# Epoch 28/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - accuracy: 0.4542 - loss: 2.5525 - val_accuracy: 0.0550 - val_loss: 11.3139
# Epoch 29/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 30s 92ms/step - accuracy: 0.4590 - loss: 2.5244 - val_accuracy: 0.0538 - val_loss: 11.3691
# Epoch 30/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 96ms/step - accuracy: 0.4596 - loss: 2.5118 - val_accuracy: 0.0546 - val_loss: 11.4067
# Epoch 31/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 98ms/step - accuracy: 0.4662 - loss: 2.4856 - val_accuracy: 0.0528 - val_loss: 11.4391
# Epoch 32/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 95ms/step - accuracy: 0.4666 - loss: 2.4518 - val_accuracy: 0.0527 - val_loss: 11.4926
# Epoch 33/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 92ms/step - accuracy: 0.4687 - loss: 2.4549 - val_accuracy: 0.0509 - val_loss: 11.5360
# Epoch 34/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 30s 95ms/step - accuracy: 0.4752 - loss: 2.4169 - val_accuracy: 0.0546 - val_loss: 11.5799
# Epoch 35/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 96ms/step - accuracy: 0.4855 - loss: 2.3954 - val_accuracy: 0.0558 - val_loss: 11.6525
# Epoch 36/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 95ms/step - accuracy: 0.4740 - loss: 2.4006 - val_accuracy: 0.0527 - val_loss: 11.6924
# Epoch 37/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 43s 103ms/step - accuracy: 0.4883 - loss: 2.3586 - val_accuracy: 0.0527 - val_loss: 11.7217
# Epoch 38/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 99ms/step - accuracy: 0.4912 - loss: 2.3471 - val_accuracy: 0.0530 - val_loss: 11.7725
# Epoch 39/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 96ms/step - accuracy: 0.4932 - loss: 2.3205 - val_accuracy: 0.0523 - val_loss: 11.7994
# Epoch 40/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.5011 - loss: 2.2898 - val_accuracy: 0.0523 - val_loss: 11.8362
# Epoch 41/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 92ms/step - accuracy: 0.5035 - loss: 2.2862 - val_accuracy: 0.0536 - val_loss: 11.8803
# Epoch 42/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 95ms/step - accuracy: 0.5061 - loss: 2.2663 - val_accuracy: 0.0515 - val_loss: 11.9256
# Epoch 43/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 97ms/step - accuracy: 0.5083 - loss: 2.2621 - val_accuracy: 0.0532 - val_loss: 11.9648
# Epoch 44/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.5125 - loss: 2.2395 - val_accuracy: 0.0544 - val_loss: 11.9862
# Epoch 45/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - accuracy: 0.5199 - loss: 2.1936 - val_accuracy: 0.0544 - val_loss: 12.0358
# Epoch 46/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 95ms/step - accuracy: 0.5175 - loss: 2.1945 - val_accuracy: 0.0538 - val_loss: 12.0448
# Epoch 47/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 97ms/step - accuracy: 0.5221 - loss: 2.1767 - val_accuracy: 0.0528 - val_loss: 12.0975
# Epoch 48/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.5271 - loss: 2.1829 - val_accuracy: 0.0511 - val_loss: 12.1350
# Epoch 49/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 98ms/step - accuracy: 0.5324 - loss: 2.1443 - val_accuracy: 0.0503 - val_loss: 12.1820
# Epoch 50/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 98ms/step - accuracy: 0.5354 - loss: 2.1417 - val_accuracy: 0.0530 - val_loss: 12.2338
# Epoch 51/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 98ms/step - accuracy: 0.5396 - loss: 2.1115 - val_accuracy: 0.0519 - val_loss: 12.2817
# Epoch 52/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 94ms/step - accuracy: 0.5434 - loss: 2.0934 - val_accuracy: 0.0544 - val_loss: 12.3024
# Epoch 53/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.5474 - loss: 2.0662 - val_accuracy: 0.0544 - val_loss: 12.3354
# Epoch 54/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 98ms/step - accuracy: 0.5427 - loss: 2.0710 - val_accuracy: 0.0530 - val_loss: 12.3781
# Epoch 55/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 97ms/step - accuracy: 0.5485 - loss: 2.0571 - val_accuracy: 0.0532 - val_loss: 12.4501
# Epoch 56/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 92ms/step - accuracy: 0.5479 - loss: 2.0512 - val_accuracy: 0.0501 - val_loss: 12.4724
# Epoch 57/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 95ms/step - accuracy: 0.5495 - loss: 2.0254 - val_accuracy: 0.0517 - val_loss: 12.4585
# Epoch 58/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 98ms/step - accuracy: 0.5560 - loss: 2.0051 - val_accuracy: 0.0538 - val_loss: 12.5038
# Epoch 59/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 98ms/step - accuracy: 0.5570 - loss: 2.0078 - val_accuracy: 0.0530 - val_loss: 12.5573
# Epoch 60/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.5659 - loss: 1.9841 - val_accuracy: 0.0486 - val_loss: 12.5829
# Epoch 61/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - accuracy: 0.5636 - loss: 1.9652 - val_accuracy: 0.0503 - val_loss: 12.6405
# Epoch 62/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 97ms/step - accuracy: 0.5608 - loss: 1.9723 - val_accuracy: 0.0511 - val_loss: 12.6769
# Epoch 63/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 96ms/step - accuracy: 0.5736 - loss: 1.9270 - val_accuracy: 0.0521 - val_loss: 12.6668
# Epoch 64/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.5785 - loss: 1.9156 - val_accuracy: 0.0503 - val_loss: 12.7189
# Epoch 65/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 100ms/step - accuracy: 0.5802 - loss: 1.9116 - val_accuracy: 0.0530 - val_loss: 12.7579
# Epoch 66/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.5741 - loss: 1.9113 - val_accuracy: 0.0550 - val_loss: 12.7949
# Epoch 67/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 92ms/step - accuracy: 0.5822 - loss: 1.8855 - val_accuracy: 0.0532 - val_loss: 12.8245
# Epoch 68/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 96ms/step - accuracy: 0.5847 - loss: 1.8658 - val_accuracy: 0.0511 - val_loss: 12.8684
# Epoch 69/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 97ms/step - accuracy: 0.5886 - loss: 1.8503 - val_accuracy: 0.0501 - val_loss: 12.9235
# Epoch 70/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - accuracy: 0.5952 - loss: 1.8386 - val_accuracy: 0.0521 - val_loss: 12.9521
# Epoch 71/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.5896 - loss: 1.8326 - val_accuracy: 0.0513 - val_loss: 12.9713
# Epoch 72/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 101ms/step - accuracy: 0.5939 - loss: 1.8277 - val_accuracy: 0.0523 - val_loss: 12.9860
# Epoch 73/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 98ms/step - accuracy: 0.5991 - loss: 1.8265 - val_accuracy: 0.0519 - val_loss: 13.0610
# Epoch 74/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 97ms/step - accuracy: 0.5987 - loss: 1.8051 - val_accuracy: 0.0519 - val_loss: 13.0602
# Epoch 75/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 94ms/step - accuracy: 0.6045 - loss: 1.7852 - val_accuracy: 0.0507 - val_loss: 13.1105
# Epoch 76/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 97ms/step - accuracy: 0.5997 - loss: 1.8045 - val_accuracy: 0.0523 - val_loss: 13.1210
# Epoch 77/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 102ms/step - accuracy: 0.6052 - loss: 1.7602 - val_accuracy: 0.0527 - val_loss: 13.1440
# Epoch 78/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 98ms/step - accuracy: 0.6094 - loss: 1.7487 - val_accuracy: 0.0536 - val_loss: 13.1985
# Epoch 79/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 98ms/step - accuracy: 0.6131 - loss: 1.7322 - val_accuracy: 0.0519 - val_loss: 13.2013
# Epoch 80/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 95ms/step - accuracy: 0.6186 - loss: 1.7166 - val_accuracy: 0.0484 - val_loss: 13.2241
# Epoch 81/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 98ms/step - accuracy: 0.6135 - loss: 1.7218 - val_accuracy: 0.0528 - val_loss: 13.2825
# Epoch 82/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.6171 - loss: 1.6989 - val_accuracy: 0.0517 - val_loss: 13.3024
# Epoch 83/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.6195 - loss: 1.6841 - val_accuracy: 0.0521 - val_loss: 13.3541
# Epoch 84/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 96ms/step - accuracy: 0.6277 - loss: 1.6841 - val_accuracy: 0.0511 - val_loss: 13.3601
# Epoch 85/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 99ms/step - accuracy: 0.6169 - loss: 1.6750 - val_accuracy: 0.0519 - val_loss: 13.3992
# Epoch 86/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 98ms/step - accuracy: 0.6245 - loss: 1.6585 - val_accuracy: 0.0499 - val_loss: 13.4413
# Epoch 87/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - accuracy: 0.6319 - loss: 1.6524 - val_accuracy: 0.0507 - val_loss: 13.4746
# Epoch 88/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 33s 101ms/step - accuracy: 0.6393 - loss: 1.6172 - val_accuracy: 0.0523 - val_loss: 13.4911
# Epoch 89/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 33s 102ms/step - accuracy: 0.6454 - loss: 1.6019 - val_accuracy: 0.0527 - val_loss: 13.5290
# Epoch 90/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 100ms/step - accuracy: 0.6393 - loss: 1.5986 - val_accuracy: 0.0538 - val_loss: 13.5565
# Epoch 91/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - accuracy: 0.6451 - loss: 1.5979 - val_accuracy: 0.0519 - val_loss: 13.5531
# Epoch 92/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 100ms/step - accuracy: 0.6404 - loss: 1.6156 - val_accuracy: 0.0525 - val_loss: 13.5605
# Epoch 93/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - accuracy: 0.6405 - loss: 1.5876 - val_accuracy: 0.0511 - val_loss: 13.6105
# Epoch 94/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.6472 - loss: 1.5717 - val_accuracy: 0.0507 - val_loss: 13.6595
# Epoch 95/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 30s 94ms/step - accuracy: 0.6411 - loss: 1.5918 - val_accuracy: 0.0517 - val_loss: 13.6894
# Epoch 96/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 30s 93ms/step - accuracy: 0.6429 - loss: 1.5776 - val_accuracy: 0.0493 - val_loss: 13.7126
# Epoch 97/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 92ms/step - accuracy: 0.6514 - loss: 1.5427 - val_accuracy: 0.0499 - val_loss: 13.7714
# Epoch 98/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.6494 - loss: 1.5468 - val_accuracy: 0.0515 - val_loss: 13.7851
# Epoch 99/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.6517 - loss: 1.5433 - val_accuracy: 0.0501 - val_loss: 13.8188
# Epoch 100/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 30s 94ms/step - accuracy: 0.6534 - loss: 1.5401 - val_accuracy: 0.0525 - val_loss: 13.8529
# Epoch 101/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.6496 - loss: 1.5414 - val_accuracy: 0.0523 - val_loss: 13.8334
# Epoch 102/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - accuracy: 0.6570 - loss: 1.5043 - val_accuracy: 0.0503 - val_loss: 13.8962
# Epoch 103/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 96ms/step - accuracy: 0.6582 - loss: 1.5113 - val_accuracy: 0.0509 - val_loss: 13.9238
# Epoch 104/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.6601 - loss: 1.4969 - val_accuracy: 0.0523 - val_loss: 13.9437
# Epoch 105/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 95ms/step - accuracy: 0.6656 - loss: 1.4674 - val_accuracy: 0.0513 - val_loss: 13.9416
# Epoch 106/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.6690 - loss: 1.4757 - val_accuracy: 0.0519 - val_loss: 14.0109
# Epoch 107/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - accuracy: 0.6631 - loss: 1.4736 - val_accuracy: 0.0521 - val_loss: 13.9938
# Epoch 108/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 30s 94ms/step - accuracy: 0.6659 - loss: 1.4723 - val_accuracy: 0.0521 - val_loss: 14.0511
# Epoch 109/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - accuracy: 0.6731 - loss: 1.4346 - val_accuracy: 0.0528 - val_loss: 14.0622
# Epoch 110/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 97ms/step - accuracy: 0.6711 - loss: 1.4497 - val_accuracy: 0.0525 - val_loss: 14.0999
# Epoch 111/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.6717 - loss: 1.4376 - val_accuracy: 0.0513 - val_loss: 14.1486
# Epoch 112/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.6765 - loss: 1.4226 - val_accuracy: 0.0530 - val_loss: 14.1089
# Epoch 113/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.6747 - loss: 1.4254 - val_accuracy: 0.0519 - val_loss: 14.1941
# Epoch 114/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 100ms/step - accuracy: 0.6823 - loss: 1.3980 - val_accuracy: 0.0509 - val_loss: 14.2069
# Epoch 115/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 96ms/step - accuracy: 0.6843 - loss: 1.3839 - val_accuracy: 0.0513 - val_loss: 14.2320
# Epoch 116/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 100ms/step - accuracy: 0.6874 - loss: 1.3838 - val_accuracy: 0.0519 - val_loss: 14.2485
# Epoch 117/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 38s 93ms/step - accuracy: 0.6832 - loss: 1.3846 - val_accuracy: 0.0503 - val_loss: 14.2783
# Epoch 118/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 95ms/step - accuracy: 0.6830 - loss: 1.3880 - val_accuracy: 0.0501 - val_loss: 14.3274
# Epoch 119/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.6852 - loss: 1.3764 - val_accuracy: 0.0474 - val_loss: 14.3265
# Epoch 120/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.6897 - loss: 1.3585 - val_accuracy: 0.0503 - val_loss: 14.3456
# Epoch 121/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 95ms/step - accuracy: 0.6925 - loss: 1.3589 - val_accuracy: 0.0482 - val_loss: 14.3643
# Epoch 122/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.6984 - loss: 1.3232 - val_accuracy: 0.0515 - val_loss: 14.4034
# Epoch 123/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 95ms/step - accuracy: 0.6981 - loss: 1.3320 - val_accuracy: 0.0503 - val_loss: 14.4180
# Epoch 124/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.6926 - loss: 1.3383 - val_accuracy: 0.0525 - val_loss: 14.4450
# Epoch 125/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 39s 95ms/step - accuracy: 0.6983 - loss: 1.3212 - val_accuracy: 0.0515 - val_loss: 14.4583
# Epoch 126/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.7009 - loss: 1.3151 - val_accuracy: 0.0519 - val_loss: 14.5241
# Epoch 127/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.7055 - loss: 1.2941 - val_accuracy: 0.0519 - val_loss: 14.5208
# Epoch 128/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 97ms/step - accuracy: 0.6991 - loss: 1.3147 - val_accuracy: 0.0521 - val_loss: 14.5698
# Epoch 129/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 98ms/step - accuracy: 0.6991 - loss: 1.3080 - val_accuracy: 0.0513 - val_loss: 14.5951
# Epoch 130/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 97ms/step - accuracy: 0.7001 - loss: 1.2988 - val_accuracy: 0.0521 - val_loss: 14.6440
# Epoch 131/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 97ms/step - accuracy: 0.7033 - loss: 1.2927 - val_accuracy: 0.0536 - val_loss: 14.6557
# Epoch 132/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 99ms/step - accuracy: 0.7101 - loss: 1.2693 - val_accuracy: 0.0525 - val_loss: 14.6647
# Epoch 133/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 101ms/step - accuracy: 0.7110 - loss: 1.2516 - val_accuracy: 0.0505 - val_loss: 14.7143
# Epoch 134/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 98ms/step - accuracy: 0.7122 - loss: 1.2508 - val_accuracy: 0.0523 - val_loss: 14.7271
# Epoch 135/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.7149 - loss: 1.2535 - val_accuracy: 0.0493 - val_loss: 14.7534
# Epoch 136/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 96ms/step - accuracy: 0.7109 - loss: 1.2541 - val_accuracy: 0.0499 - val_loss: 14.7475
# Epoch 137/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 30s 95ms/step - accuracy: 0.7198 - loss: 1.2254 - val_accuracy: 0.0528 - val_loss: 14.7861
# Epoch 138/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 97ms/step - accuracy: 0.7127 - loss: 1.2473 - val_accuracy: 0.0530 - val_loss: 14.7889
# Epoch 139/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 95ms/step - accuracy: 0.7159 - loss: 1.2378 - val_accuracy: 0.0505 - val_loss: 14.8323
# Epoch 140/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - accuracy: 0.7213 - loss: 1.2259 - val_accuracy: 0.0509 - val_loss: 14.8718
# Epoch 141/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.7170 - loss: 1.2237 - val_accuracy: 0.0509 - val_loss: 14.8865
# Epoch 142/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.7223 - loss: 1.2044 - val_accuracy: 0.0523 - val_loss: 14.9117
# Epoch 143/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 98ms/step - accuracy: 0.7212 - loss: 1.2100 - val_accuracy: 0.0523 - val_loss: 14.9177
# Epoch 144/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 31s 98ms/step - accuracy: 0.7180 - loss: 1.2142 - val_accuracy: 0.0525 - val_loss: 14.9511
# Epoch 145/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 97ms/step - accuracy: 0.7255 - loss: 1.1922 - val_accuracy: 0.0515 - val_loss: 14.9866
# Epoch 146/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.7260 - loss: 1.1727 - val_accuracy: 0.0540 - val_loss: 14.9936
# Epoch 147/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 97ms/step - accuracy: 0.7289 - loss: 1.2027 - val_accuracy: 0.0544 - val_loss: 14.9974
# Epoch 148/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 40s 95ms/step - accuracy: 0.7269 - loss: 1.1802 - val_accuracy: 0.0519 - val_loss: 15.0244
# Epoch 149/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.7191 - loss: 1.1971 - val_accuracy: 0.0517 - val_loss: 15.0286
# Epoch 150/150
# 322/322 ━━━━━━━━━━━━━━━━━━━━ 32s 98ms/step - accuracy: 0.7334 - loss: 1.1666 - val_accuracy: 0.0530 - val_loss: 15.0753

# %%
# Function to predict the next word
def predict_next_word(model, tokenizer, text, max_sequence_len):
    token_list = tokenizer.texts_to_sequences([text])[0]
    if len(token_list) >= max_sequence_len:
        token_list = token_list[-(max_sequence_len-1):]  # Ensure the sequence length matches max_sequence_len-1
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = model.predict(token_list, verbose=0)
    predicted_word_index = np.argmax(predicted, axis=1)
    for word, index in tokenizer.word_index.items():
        if index == predicted_word_index:
            return word
    return None

# %%
input_text="To be or not to be"
print(f"Input text:{input_text}")
max_sequence_len=model.input_shape[1]+1
next_word=predict_next_word(model,tokenizer,input_text,max_sequence_len)
print(f"Next Word PRediction:{next_word}")
# Out:
# Input text:To be or not to be
# Next Word PRediction:that

# %%
## Save the model
model.save("next_word_lstm.h5")
## Save the tokenizer
import pickle
with open('tokenizer.pickle','wb') as handle:
    pickle.dump(tokenizer,handle,protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
input_text="  Barn. Last night of all,When yond same"
print(f"Input text:{input_text}")
max_sequence_len=model.input_shape[1]+1
next_word=predict_next_word(model,tokenizer,input_text,max_sequence_len)
print(f"Next Word PRediction:{next_word}")
# Out:
# Input text:  Barn. Last night of all,When yond same
# Next Word PRediction:eyes
